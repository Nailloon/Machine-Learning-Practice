# %% [markdown]
# <a href="https://colab.research.google.com/github/Nailloon/Machine-Learning-Practice/blob/main/%D0%92%D1%81%D0%BF%D0%BE%D0%BC%D0%BE%D0%B3%D0%B0%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5%20%D0%BC%D0%B0%D1%82%D0%B5%D1%80%D0%B8%D0%B0%D0%BB%D1%8B/%D0%A0%D0%B0%D0%B1%D0%BE%D1%82%D0%B0%20%D1%81%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8%20%D0%B2%20pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ##Создание (загрузка) данных

# %%
data1 = pd.DataFrame(columns=['Id', 'Name', 'Age'], data=[
    [14, 'Artem', 20],
    [19, 'Alexey', 34],
    [18, 'Katya', None]
])
data1
# Out:
#    Id    Name   Age
# 0  14   Artem  20.0
# 1  19  Alexey  34.0
# 2  18   Katya   NaN

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive"
# Out:
# '2022-05-22 21-47-28.mkv'
# '3 миссия.gdoc'
# 'Colab Notebooks'
#  DemoContent.gdoc
# 'Акторы: абитуриент.gdoc'
# 'Вопросы для интервью.gdoc'
# 'Вопросы для теста по дизайн-мышлению.gdoc'
# 'Гайд интервью.gdoc'
#  Доклад.gdoc
# ' Команда 12, Юдинцева к1с1.gdoc'
# 'Копия Titulnik_DZ_proektnaya_deyatelnost_MO 211.docx'
# 'Личный отчет.gdoc'
# 'Методичка поДМ.gdoc'
# 'Новый документ (10).gdoc'
# 'Новый документ (11).gdoc'
# 'Новый документ (12).gdoc'
# 'Новый документ (1).gdoc'
# 'Новый документ (2).gdoc'
# 'Новый документ (3).gdoc'
# 'Новый документ (4).gdoc'
# 'Новый документ (5).gdoc'
# 'Новый документ (6).gdoc'
# 'Новый документ (7).gdoc'
# 'Новый документ (8).gdoc'
# 'Новый документ (9).gdoc'
# 'Новый документ.gdoc'
# 'описание профессий.gdoc'
#  Практикум
# 'Приватизация .gdoc'
# ' Протоколы тестирования, профессии в IT.gsheet'
# 'Результаты интервью.gdoc'

# %%
data2 = pd.read_csv("/content/drive/MyDrive/")
data2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-83592fa3d61f> in <module>
# ----> 1 data2 = pd.read_csv("/content/drive/MyDrive/bank_churners.csv")
#       2 data2
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data2.head(3)

# %%
data2.tail(2)

# %%
data2.drop(columns=["CLIENTNUM"], inplace=True)

# %%
data3 = pd.DataFrame(columns=['Id', 'Name', 'Age'], data=[
    [7, 'Artem', 20],
])
data3
# Out:
#    Id   Name  Age
# 0   7  Artem   20

# %%
concat_data = pd.concat(objs=[data1, data3], axis=0)
concat_data
# Out:
#    Id    Name   Age
# 0  14   Artem  20.0
# 1  19  Alexey  34.0
# 2  18   Katya   NaN
# 0   7   Artem  20.0

# %%
concat_data = concat_data.drop_duplicates()
concat_data
# Out:
#    Id    Name   Age
# 0  14   Artem  20.0
# 1  19  Alexey  34.0
# 2  18   Katya   NaN
# 0   7   Artem  20.0

# %%
concat_data.set_index(keys="Id", inplace=True)
concat_data
# Out:
#       Name   Age
# Id
# 14   Artem  20.0
# 19  Alexey  34.0
# 18   Katya   NaN
# 7    Artem  20.0

# %%
concat_data.sort_index(inplace=True)
concat_data
# Out:
#       Name   Age
# Id
# 7    Artem  20.0
# 14   Artem  20.0
# 18   Katya   NaN
# 19  Alexey  34.0

# %%
concat_data.sort_values(by="Name", inplace=True)
concat_data
# Out:
#       Name   Age
# Id
# 19  Alexey  34.0
# 7    Artem  20.0
# 14   Artem  20.0
# 18   Katya   NaN

# %%
data2.describe()

# %%
data2.info()

# %%
data2.columns.values.tolist()

# %%
data1.columns = ['Identificator', 'Imya', 'Vosrast']
data1
# Out:
#    Identificator    Imya  Vosrast
# 0             14   Artem     20.0
# 1             19  Alexey     34.0
# 2             18   Katya      NaN

# %%
ages = data2['Age'].values

# %%
data1.set_index(keys = ["Identificator"], inplace=True)

# %%
data1.iloc[1]
# Out:
# Imya       Alexey
# Vosrast      34.0
# Name: 19, dtype: object

# %%
data1.loc[14]
# Out:
# Imya       Artem
# Vosrast     20.0
# Name: 14, dtype: object

# %%
data2[(data2['Gender']== 'M') & (data2['Age']>= 50)]

# %%
oldi.to_csv('/content/drive/MyDrive/oldi.csv')

# %%
map_dict = {
    'M': 0,
    'F': 1
}

# %%
data2['Gender'] = data2['Gender'].map(map_dict)

# %%
import numpy
numpy.unique(data2['Flag'].values)
