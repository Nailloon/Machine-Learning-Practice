# %% [markdown]
# <a href="https://colab.research.google.com/github/Nailloon/Machine-Learning-Practice/blob/main/%D0%92%D1%81%D0%BF%D0%BE%D0%BC%D0%BE%D0%B3%D0%B0%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5%20%D0%BC%D0%B0%D1%82%D0%B5%D1%80%D0%B8%D0%B0%D0%BB%D1%8B/%D0%A0%D0%B0%D0%B1%D0%BE%D1%82%D0%B0%20%D1%81%20%D0%B4%D0%B0%D1%82%D0%B0%D1%81%D0%B5%D1%82%D0%B0%D0%BC%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ##Задание 1

# %%
data1 = pd.DataFrame(columns=['Name', 'Age', 'Sex'], data=[
    ['Strom, Mrs. Wilhelm (Elna Matilda Persson)', 29, 'female'],
    ['Navratil, Mr. Michel ("Louis M Hoffman")', 36.5, 'male'],
    ['Minahan, Miss. Daisy E', 33, 'female']
])
data1
# Out:
#                                          Name   Age     Sex
# 0  Strom, Mrs. Wilhelm (Elna Matilda Persson)  29.0  female
# 1    Navratil, Mr. Michel ("Louis M Hoffman")  36.5    male
# 2                      Minahan, Miss. Daisy E  33.0  female

# %% [markdown]
# ##Задание 2

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
data2 = pd.read_csv("/content/drive/MyDrive/titanic_csv.csv", sep=';')
data2
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0            454         1       1              Goldenberg, Mr. Samuel L
# 1            234         1       3        Asplund, Miss. Lillian Gertrud
# 2            556         0       1                    Wright, Mr. George
# 3            766         1       1  Hogeboom, Mrs. John C (Anna Andrews)
# 4            444         1       2             Reynaldo, Ms. Encarnacion
# ..           ...       ...     ...                                   ...
# 489          363         0       3       Barbara, Mrs. (Catherine David)
# 490          447         1       2     Mellinger, Miss. Madeleine Violet
# 491           95         0       3                     Coxon, Mr. Daniel
# 492           59         1       2          West, Miss. Constance Mirium
# 493           33         1       3              Glynn, Miss. Mary Agatha
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ##Задание 3

# %%
data3 = pd.read_csv("https://gist.githubusercontent.com/zaryanezrya/8b4ef51c707cb16d5e88a44dc00a1bb2/raw/41230f49c6268e072dbf102672f670be256922ab/gistfile1.txt ")
data3
# Out:
#      passengerid  survived  pclass  \
# 0            552         0       2
# 1            689         0       3
# 2            605         1       1
# 3            305         0       3
# 4            290         1       3
# ..           ...       ...     ...
# 495          482         0       2
# 496          155         0       3
# 497          851         0       3
# 498          850         1       1
# 499           77         0       3
#
#                                              name     sex   age  sibsp  parch  \
# 0                     Sharp, Mr. Percival James R    male  27.0      0      0
# 1                 Fischer, Mr. Eberhard Thelander    male  18.0      0      0
# 2                 Homer, Mr. Harry ("Mr E Haven")    male  35.0      0      0
# 3               Williams, Mr. Howard Hugh "Harry"    male   NaN      0      0
# 4                            Connolly, Miss. Kate  female  22.0      0      0
# ...

# %% [markdown]
# ##Задание 4

# %%
data3.columns = data2.columns
concat_data = pd.concat(objs=[data2, data3], axis=0)
concat_data = concat_data.drop_duplicates()
concat_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            454         1       1
# 1            234         1       3
# 2            556         0       1
# 3            766         1       1
# 4            444         1       2
# ..           ...       ...     ...
# 493          445         1       3
# 494          640         0       3
# 497          851         0       3
# 498          850         1       1
# 499           77         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                        Goldenberg, Mr. Samuel L    male  49.0      1      0
# 1                  Asplund, Miss. Lillian Gertrud  female   5.0      4      2
# 2                              Wright, Mr. George    male  62.0      0      0
# 3            Hogeboom, Mrs. John C (Anna Andrews)  female  51.0      1      0
# 4                       Reynaldo, Ms. Encarnacion  female  28.0      0      0
# ...

# %% [markdown]
# ##Задание 5

# %%
concat_data.set_index(keys="PassengerId", inplace=True)
concat_data.sort_index(inplace=True)
concat_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ##Задание 6

# %%
concat_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
concat_data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ##Задание 7

# %%
a = concat_data.loc[2]
concat_data.loc[2] = concat_data.iloc[0]
concat_data.iloc[0] = a
concat_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   1       1
# 2                   0       3
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                      Braund, Mr. Owen Harris    male  22.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ##Задание 8

# %%
map_dict = {
    'female': 'f',
    'male': 'm'
}
concat_data['Sex'] = concat_data['Sex'].map(map_dict)
concat_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   1       1
# 2                   0       3
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name Sex   Age  \
# PassengerId
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0
# 2                                      Braund, Mr. Owen Harris   m  22.0
# 3                                       Heikkinen, Miss. Laina   f  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   f  35.0
# 5                                     Allen, Mr. William Henry   m  35.0
# ...                                                        ...  ..   ...
# ...

# %% [markdown]
# ##Задание 9

# %%
tickets = concat_data.groupby(['Ticket']).filter(lambda x: len(x) >= 6)
t = tickets['Ticket'].values
t
# Out:
# array(['347082', '3101295', 'CA 2144', '347088', 'CA 2144', '1601',
#        '347082', 'CA. 2343', '3101295', '347088', '1601', 'CA. 2343',
#        'CA. 2343', '3101295', 'CA. 2343', '347088', 'CA 2144', 'CA 2144',
#        '1601', '347082', '347082', '347082', '347088', '3101295',
#        '347088', '1601', 'CA 2144', 'CA 2144', '3101295', '1601',
#        'CA. 2343', '347082', '347088', '3101295', '1601', '1601',
#        'CA. 2343', '347082', 'CA. 2343'], dtype=object)

# %%
people = tickets['Name'].values
people
# Out:
# array(['Andersson, Mr. Anders Johan', 'Panula, Master. Juha Niilo',
#        'Goodwin, Master. William Frederick', 'Skoog, Master. Harald',
#        'Goodwin, Miss. Lillian Amy', 'Bing, Mr. Lee',
#        'Andersson, Miss. Ellis Anna Maria', 'Sage, Master. Thomas Henry',
#        'Panula, Master. Eino Viljami',
#        'Skoog, Mrs. William (Anna Bernhardina Karlsson)', 'Ling, Mr. Lee',
#        'Sage, Miss. Constance Gladys', 'Sage, Mr. Frederick',
#        'Panula, Mr. Ernesti Arvid', 'Sage, Mr. George John Jr',
#        'Skoog, Mr. Wilhelm', 'Goodwin, Master. Sidney Leonard',
#        'Goodwin, Master. Harold Victor', 'Lang, Mr. Fang',
#        'Andersson, Miss. Ingeborg Constanzia',
#        'Andersson, Miss. Sigrid Elisabeth',
#        'Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)',
#        'Skoog, Miss. Mabel', 'Panula, Mrs. Juha (Maria Emilia Ojala)',
#        'Skoog, Miss. Margit Elizabeth', 'Foo, Mr. Choong',
#        'Goodwin, Mrs. Frederick (Augusta Tyler)',
# ...

# %% [markdown]
# ##Задание 10

# %%
c = concat_data.loc[concat_data['Name'].isin(data1['Name'])]
c
# Out:
#              Survived  Pclass                                        Name Sex  \
# PassengerId
# 149                 0       2    Navratil, Mr. Michel ("Louis M Hoffman")   m
# 252                 0       3  Strom, Mrs. Wilhelm (Elna Matilda Persson)   f
# 413                 1       1                      Minahan, Miss. Daisy E   f
#
#               Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# PassengerId
# 149          36.5      0      2  230080  26.0000    F2        S
# 252          29.0      1      1  347054  10.4625    G6        S
# 413          33.0      1      0   19928  90.0000   C78        Q

# %%
d = concat_data.loc[concat_data['Cabin'].isin(c['Cabin'])]
d
# Out:
#              Survived  Pclass  \
# PassengerId
# 11                  1       3
# 149                 0       2
# 194                 1       2
# 206                 0       3
# 246                 0       1
# 252                 0       3
# 341                 1       2
# 395                 1       3
# 413                 1       1
#
#                                                           Name Sex   Age  \
# PassengerId
# 11                             Sandstrom, Miss. Marguerite Rut   f   4.0
# 149                   Navratil, Mr. Michel ("Louis M Hoffman")   m  36.5
# 194                                 Navratil, Master. Michel M   m   3.0
# 206                                 Strom, Miss. Telma Matilda   f   2.0
# 246                                Minahan, Dr. William Edward   m  44.0
# 252                 Strom, Mrs. Wilhelm (Elna Matilda Persson)   f  29.0
# 341                             Navratil, Master. Edmond Roger   m   2.0
# ...

# %% [markdown]
# ##Задание 11

# %%
year = concat_data.assign(BirthYear = 1912 - concat_data.Age)
year
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   1       1
# 2                   0       3
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name Sex   Age  \
# PassengerId
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0
# 2                                      Braund, Mr. Owen Harris   m  22.0
# 3                                       Heikkinen, Miss. Laina   f  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   f  35.0
# 5                                     Allen, Mr. William Henry   m  35.0
# ...                                                        ...  ..   ...
# ...

# %% [markdown]
# ##Задание 12

# %%
s = concat_data.dropna(subset = ['Cabin'])
values = s['Cabin'].value_counts(dropna=False).keys().tolist()
counts = s['Cabin'].value_counts(dropna=False).tolist()
value_dict = dict(zip(values, counts))
companion = s.assign(Companion = s['Cabin'].map(value_dict)-1)
companion
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name Sex   Age  \
# PassengerId
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   f  35.0
# 7                                      McCarthy, Mr. Timothy J   m  54.0
# 11                             Sandstrom, Miss. Marguerite Rut   f   4.0
# 12                                    Bonnell, Miss. Elizabeth   f  58.0
# ...                                                        ...  ..   ...
# ...

# %% [markdown]
# ##Задание 13

# %%
r = concat_data.loc[1]
concat_data.loc[1] = concat_data.iloc[0]
concat_data.iloc[0] = r
concat_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   1       1
# 2                   0       3
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name Sex   Age  \
# PassengerId
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0
# 2                                      Braund, Mr. Owen Harris   m  22.0
# 3                                       Heikkinen, Miss. Laina   f  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   f  35.0
# 5                                     Allen, Mr. William Henry   m  35.0
# ...                                                        ...  ..   ...
# ...

# %% [markdown]
# ##Задание 14

# %%
concat_data.to_csv('/content/drive/MyDrive/LABA.csv')

# %% [markdown]
# ##Задание 15

# %%
task15 = concat_data.sort_values(by="Fare", ascending=False)
task15.head(10)
# Out:
#              Survived  Pclass                                   Name Sex  \
# PassengerId
# 259                 1       1                       Ward, Miss. Anna   f
# 680                 1       1     Cardeza, Mr. Thomas Drake Martinez   m
# 738                 1       1                 Lesurer, Mr. Gustave J   m
# 28                  0       1         Fortune, Mr. Charles Alexander   m
# 439                 0       1                      Fortune, Mr. Mark   m
# 89                  1       1             Fortune, Miss. Mabel Helen   f
# 342                 1       1         Fortune, Miss. Alice Elizabeth   f
# 743                 1       1  Ryerson, Miss. Susan Parker "Suzette"   f
# 312                 1       1             Ryerson, Miss. Emily Borie   f
# 119                 0       1               Baxter, Mr. Quigg Edmond   m
#
#               Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# PassengerId
# ...

# %% [markdown]
# ##Задание 16

# %%
concat_data.groupby(['Sex', 'Survived'])['Name'].count()
# Out:
# Sex  Survived
# f    0            81
#      1           233
# m    0           468
#      1           109
# Name: Name, dtype: int64

# %% [markdown]
# ##Задание 17

# %%
concat_data.groupby(['Pclass', 'Survived'])['Name'].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Name, dtype: int64
